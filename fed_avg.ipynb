# %%
import random
import copy

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

from util import view_10, num_params
from data import fetch_dataset, data_to_tensor, iid_partition_loader, noniid_partition_loader

# %%
# wj test
# set random seeds
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
print("| using device:", device)
# Out:
# | using device: mps

# %%
# hyperparams
bsz = 10

# %% [markdown]
# ## Data

# %%
train_data, test_data = fetch_dataset()

test_loader = torch.utils.data.DataLoader(test_data, batch_size = 1000, shuffle=False) # inference bsz=1000
debug_loader = torch.utils.data.DataLoader(train_data, bsz)
img, label = next(iter(debug_loader))
view_10(img, label)

# %%
# get client dataloaders
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
noniid_client_train_loader = noniid_partition_loader(train_data, bsz = bsz)

# %%
# iid
label_dist = torch.zeros(10)
for (x,y) in iid_client_train_loader[25]:
    label_dist+= torch.sum(F.one_hot(y, num_classes=10), dim=0)
print("iid: ", label_dist)
view_10(x,y)
# Out:
# iid:  tensor([59., 67., 65., 61., 55., 52., 55., 64., 48., 74.])

# %%
# non-iid
label_dist = torch.zeros(10)
for (x,y) in noniid_client_train_loader[25]:
    label_dist+= torch.sum(F.one_hot(y,num_classes=10), dim=0)
print("non-iid: ", label_dist)
view_10(x,y)
# Out:
# non-iid:  tensor([300.,   0.,   0., 300.,   0.,   0.,   0.,   0.,   0.,   0.])

# %% [markdown]
# ## Models

# %%
# define fully connected NN
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(784, 200);
        self.fc2 = nn.Linear(200, 200);
        self.out = nn.Linear(200, 10);

    def forward(self, x):
        x = x.flatten(1) # [B x 784]
        x = F.relu(self.fc1(x)) # [B x 200]
        x = F.relu(self.fc2(x)) # [B x 200]
        x = self.out(x) # [B x 10]
        return x

print(MLP())
print(num_params(MLP()))
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (out): Linear(in_features=200, out_features=10, bias=True)
# )
# 199210

# %%
# define cnn
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5) 
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.fc = nn.Linear(1024, 512)
        self.out = nn.Linear(512, 10)

    def forward(self, x):
        x = F.max_pool2d(self.conv1(x), 2, 2) # [B x 32 x 12 x 12]
        x = F.max_pool2d(self.conv2(x), 2, 2) # [B x 64 x 4 x 4]
        x = x.flatten(1) # [B x 1024]
        x = F.relu(self.fc(x)) # [B x 512]
        x = self.out(x) # [B x 10]
        return x

print(CNN())
print(num_params(CNN()))
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=10, bias=True)
# )
# 582026

# %% [markdown]
# ## Training

# %%
criterion = nn.CrossEntropyLoss()

def validate(model):
    model = model.to(device)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            out = model(x)
            correct += torch.sum(torch.argmax(out, dim=1) == y).item()
            total += x.shape[0]
    return correct/total

# %%
def train_client(id, client_loader, global_model, num_local_epochs, lr):
    local_model = copy.deepcopy(global_model)
    local_model = local_model.to(device)
    local_model.train()
    optimizer = torch.optim.SGD(local_model.parameters(), lr=lr)

    for epoch in range(num_local_epochs):
        for (i, (x,y)) in enumerate(client_loader):
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            out = local_model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

    return local_model

def running_model_avg(current, next, scale):
    if current == None:
        current = next
        for key in current:
            current[key] = current[key] * scale
    else:
        for key in current:
            current[key] = current[key] + (next[key] * scale)
    return current

# %%
def fed_avg_experiment(global_model, num_clients_per_round, num_local_epochs, lr, client_train_loader, max_rounds, filename):
    round_accuracy = []
    for t in range(max_rounds):
        print("starting round {}".format(t))

        # choose clients
        clients = np.random.choice(np.arange(100), num_clients_per_round, replace = False)
        print("clients: ", clients)

        global_model.eval()
        global_model = global_model.to(device)
        running_avg = None

        for i,c in enumerate(clients):
            # train local client
            print("round {}, starting client {}/{}, id: {}".format(t, i+1,num_clients_per_round, c))
            local_model = train_client(c, client_train_loader[c], global_model, num_local_epochs, lr)

            # add local model parameters to running average
            running_avg = running_model_avg(running_avg, local_model.state_dict(), 1/num_clients_per_round)
        
        # set global model parameters for the next step
        global_model.load_state_dict(running_avg)

        # validate
        val_acc = validate(global_model)
        print("round {}, validation acc: {}".format(t, val_acc))
        round_accuracy.append(val_acc)

        if (t % 10 == 0):
          np.save(filename+'_{}'.format(t)+'.npy', np.array(round_accuracy))

    return np.array(round_accuracy)

# %% [markdown]
#  ## MLP experiments

# %%
mlp = MLP()
print(mlp)
print("total params: ", num_params(mlp))
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (out): Linear(in_features=200, out_features=10, bias=True)
# )
# total params:  199210

# %%
# MLP - iid - m=10 experiment
mlp_iid_m10 = copy.deepcopy(mlp)
acc_mlp_iid_m10 = fed_avg_experiment(mlp_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=10,
                                 filename='./acc_mlp_iid_m10')
print(acc_mlp_iid_m10)
np.save('./acc_mlp_iid_m10.npy', acc_mlp_iid_m10)
# Out:
# starting round 0
# clients:  [24 93 94 29 79 25 58 96 87 11]
# round 0, starting client 1/10, id: 24
# round 0, starting client 2/10, id: 93
# round 0, starting client 3/10, id: 94
# round 0, starting client 4/10, id: 29
# round 0, starting client 5/10, id: 79
# round 0, starting client 6/10, id: 25
# round 0, starting client 7/10, id: 58
# round 0, starting client 8/10, id: 96
# round 0, starting client 9/10, id: 87
# round 0, starting client 10/10, id: 11
# round 0, validation acc: 0.8001
# starting round 1
# clients:  [59 25 91 84 75 38 27 46 87 15]
# round 1, starting client 1/10, id: 59
# round 1, starting client 2/10, id: 25
# round 1, starting client 3/10, id: 91
# round 1, starting client 4/10, id: 84
# round 1, starting client 5/10, id: 75
# round 1, starting client 6/10, id: 38
# round 1, starting client 7/10, id: 27
# round 1, starting client 8/10, id: 46
# round 1, starting client 9/10, id: 87
# round 1, starting client 10/10, id: 15
# round 1, validation acc: 0.8757
# starting round 2
# clients:  [ 1 36 89 52  2 58 15 67 96 59]
# round 2, starting client 1/10, id: 1
# round 2, starting client 2/10, id: 36
# round 2, starting client 3/10, id: 89
# round 2, starting client 4/10, id: 52
# round 2, starting client 5/10, id: 2
# round 2, starting client 6/10, id: 58
# round 2, starting client 7/10, id: 15
# round 2, starting client 8/10, id: 67
# round 2, starting client 9/10, id: 96
# round 2, starting client 10/10, id: 59
# round 2, validation acc: 0.8965
# starting round 3
# clients:  [57 25 96 86 44 59 41 76 20 45]
# round 3, starting client 1/10, id: 57
# round 3, starting client 2/10, id: 25
# round 3, starting client 3/10, id: 96
# round 3, starting client 4/10, id: 86
# round 3, starting client 5/10, id: 44
# round 3, starting client 6/10, id: 59
# round 3, starting client 7/10, id: 41
# round 3, starting client 8/10, id: 76
# round 3, starting client 9/10, id: 20
# round 3, starting client 10/10, id: 45
# round 3, validation acc: 0.9033
# starting round 4
# clients:  [39 90 27 32 56 34 13 97 17 41]
# round 4, starting client 1/10, id: 39
# round 4, starting client 2/10, id: 90
# round 4, starting client 3/10, id: 27
# round 4, starting client 4/10, id: 32
# round 4, starting client 5/10, id: 56
# round 4, starting client 6/10, id: 34
# round 4, starting client 7/10, id: 13
# round 4, starting client 8/10, id: 97
# round 4, starting client 9/10, id: 17
# round 4, starting client 10/10, id: 41
# round 4, validation acc: 0.913
# starting round 5
# clients:  [80 16 56 67 84 87 74  9 57 60]
# round 5, starting client 1/10, id: 80
# round 5, starting client 2/10, id: 16
# round 5, starting client 3/10, id: 56
# round 5, starting client 4/10, id: 67
# round 5, starting client 5/10, id: 84
# round 5, starting client 6/10, id: 87
# round 5, starting client 7/10, id: 74
# round 5, starting client 8/10, id: 9
# round 5, starting client 9/10, id: 57
# round 5, starting client 10/10, id: 60
# round 5, validation acc: 0.9182
# starting round 6
# clients:  [74  0 82 42 83 86 21 79 76 93]
# round 6, starting client 1/10, id: 74
# round 6, starting client 2/10, id: 0
# round 6, starting client 3/10, id: 82
# round 6, starting client 4/10, id: 42
# round 6, starting client 5/10, id: 83
# round 6, starting client 6/10, id: 86
# round 6, starting client 7/10, id: 21
# round 6, starting client 8/10, id: 79
# round 6, starting client 9/10, id: 76
# round 6, starting client 10/10, id: 93
# round 6, validation acc: 0.9268
# starting round 7
# clients:  [19 13 21 77 37  8 56 17 96 82]
# round 7, starting client 1/10, id: 19
# round 7, starting client 2/10, id: 13
# round 7, starting client 3/10, id: 21
# round 7, starting client 4/10, id: 77
# round 7, starting client 5/10, id: 37
# round 7, starting client 6/10, id: 8
# round 7, starting client 7/10, id: 56
# round 7, starting client 8/10, id: 17
# round 7, starting client 9/10, id: 96
# round 7, starting client 10/10, id: 82
# round 7, validation acc: 0.9301
# starting round 8
# clients:  [72 91 59 71  4 60 11 67 20 41]
# round 8, starting client 1/10, id: 72
# round 8, starting client 2/10, id: 91
# round 8, starting client 3/10, id: 59
# round 8, starting client 4/10, id: 71
# round 8, starting client 5/10, id: 4
# round 8, starting client 6/10, id: 60
# round 8, starting client 7/10, id: 11
# round 8, starting client 8/10, id: 67
# round 8, starting client 9/10, id: 20
# round 8, starting client 10/10, id: 41
# round 8, validation acc: 0.935
# starting round 9
# clients:  [99 92 71 42 59 29 76 34 33 88]
# round 9, starting client 1/10, id: 99
# round 9, starting client 2/10, id: 92
# round 9, starting client 3/10, id: 71
# round 9, starting client 4/10, id: 42
# round 9, starting client 5/10, id: 59
# round 9, starting client 6/10, id: 29
# round 9, starting client 7/10, id: 76
# round 9, starting client 8/10, id: 34
# round 9, starting client 9/10, id: 33
# round 9, starting client 10/10, id: 88
# round 9, validation acc: 0.9387
# [0.8001 0.8757 0.8965 0.9033 0.913  0.9182 0.9268 0.9301 0.935  0.9387]

# %%
# MLP - iid - m=50 experiment
mlp_iid_m50 = copy.deepcopy(mlp)
acc_mlp_iid_m50 = fed_avg_experiment(mlp_iid_m50, num_clients_per_round=50, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=10,
                                 filename='./acc_mlp_iid_m50')
print(acc_mlp_iid_m50)
np.save('./acc_mlp_iid_m50.npy', acc_mlp_iid_m50)
# Out:
# starting round 0
# clients:  [49 99 42 80 69 86 50 34 29 55 90 77 74 82 45 83 51  0 12 18 22 31 89 68
#  26 13 81 60 20 19 70 62 78 44 65 16 23 59  3 17 61 56 94 46 52 39  8 48
#  87 64]
# round 0, starting client 1/50, id: 49
# round 0, starting client 2/50, id: 99
# round 0, starting client 3/50, id: 42
# round 0, starting client 4/50, id: 80
# round 0, starting client 5/50, id: 69
# round 0, starting client 6/50, id: 86
# round 0, starting client 7/50, id: 50
# round 0, starting client 8/50, id: 34
# round 0, starting client 9/50, id: 29
# round 0, starting client 10/50, id: 55
# round 0, starting client 11/50, id: 90
# round 0, starting client 12/50, id: 77
# round 0, starting client 13/50, id: 74
# round 0, starting client 14/50, id: 82
# round 0, starting client 15/50, id: 45
# round 0, starting client 16/50, id: 83
# round 0, starting client 17/50, id: 51
# round 0, starting client 18/50, id: 0
# round 0, starting client 19/50, id: 12
# round 0, starting client 20/50, id: 18
# round 0, starting client 21/50, id: 22
# round 0, starting client 22/50, id: 31
# round 0, starting client 23/50, id: 89
# round 0, starting client 24/50, id: 68
# round 0, starting client 25/50, id: 26
# round 0, starting client 26/50, id: 13
# round 0, starting client 27/50, id: 81
# round 0, starting client 28/50, id: 60
# round 0, starting client 29/50, id: 20
# round 0, starting client 30/50, id: 19
# round 0, starting client 31/50, id: 70
# round 0, starting client 32/50, id: 62
# round 0, starting client 33/50, id: 78
# round 0, starting client 34/50, id: 44
# round 0, starting client 35/50, id: 65
# round 0, starting client 36/50, id: 16
# round 0, starting client 37/50, id: 23
# round 0, starting client 38/50, id: 59
# round 0, starting client 39/50, id: 3
# round 0, starting client 40/50, id: 17
# round 0, starting client 41/50, id: 61
# round 0, starting client 42/50, id: 56
# round 0, starting client 43/50, id: 94
# round 0, starting client 44/50, id: 46
# round 0, starting client 45/50, id: 52
# round 0, starting client 46/50, id: 39
# round 0, starting client 47/50, id: 8
# round 0, starting client 48/50, id: 48
# round 0, starting client 49/50, id: 87
# round 0, starting client 50/50, id: 64
# round 0, validation acc: 0.8165
# starting round 1
# clients:  [81 93 31 88 54 55 19 78 82 73 52  5 36 87 56 80 22 47 74 38 32 20 89 63
#  96  7 11 75 85 61 51 12 65 15 18 45 25  1 64 26 66 10 28 92 58 43 86 48
#  69 50]
# round 1, starting client 1/50, id: 81
# round 1, starting client 2/50, id: 93
# round 1, starting client 3/50, id: 31
# round 1, starting client 4/50, id: 88
# round 1, starting client 5/50, id: 54
# round 1, starting client 6/50, id: 55
# round 1, starting client 7/50, id: 19
# round 1, starting client 8/50, id: 78
# round 1, starting client 9/50, id: 82
# round 1, starting client 10/50, id: 73
# round 1, starting client 11/50, id: 52
# round 1, starting client 12/50, id: 5
# round 1, starting client 13/50, id: 36
# round 1, starting client 14/50, id: 87
# round 1, starting client 15/50, id: 56
# round 1, starting client 16/50, id: 80
# round 1, starting client 17/50, id: 22
# round 1, starting client 18/50, id: 47
# round 1, starting client 19/50, id: 74
# round 1, starting client 20/50, id: 38
# round 1, starting client 21/50, id: 32
# round 1, starting client 22/50, id: 20
# round 1, starting client 23/50, id: 89
# round 1, starting client 24/50, id: 63
# round 1, starting client 25/50, id: 96
# round 1, starting client 26/50, id: 7
# round 1, starting client 27/50, id: 11
# round 1, starting client 28/50, id: 75
# round 1, starting client 29/50, id: 85
# round 1, starting client 30/50, id: 61
# round 1, starting client 31/50, id: 51
# round 1, starting client 32/50, id: 12
# round 1, starting client 33/50, id: 65
# round 1, starting client 34/50, id: 15
# round 1, starting client 35/50, id: 18
# round 1, starting client 36/50, id: 45
# round 1, starting client 37/50, id: 25
# round 1, starting client 38/50, id: 1
# round 1, starting client 39/50, id: 64
# round 1, starting client 40/50, id: 26
# round 1, starting client 41/50, id: 66
# round 1, starting client 42/50, id: 10
# round 1, starting client 43/50, id: 28
# round 1, starting client 44/50, id: 92
# round 1, starting client 45/50, id: 58
# round 1, starting client 46/50, id: 43
# round 1, starting client 47/50, id: 86
# round 1, starting client 48/50, id: 48
# round 1, starting client 49/50, id: 69
# round 1, starting client 50/50, id: 50
# round 1, validation acc: 0.8781
# starting round 2
# clients:  [21 76  8  3 69 84 70 23 17 95 26  4 99 27 94 30 32 46 79  0 96 18 97 16
#  71 80 60 74 92 65 88 24 44 15 75 89 43 93 11 48 12  6 57 59 28 20 72 54
#  41 10]
# round 2, starting client 1/50, id: 21
# round 2, starting client 2/50, id: 76
# round 2, starting client 3/50, id: 8
# round 2, starting client 4/50, id: 3
# round 2, starting client 5/50, id: 69
# round 2, starting client 6/50, id: 84
# round 2, starting client 7/50, id: 70
# round 2, starting client 8/50, id: 23
# round 2, starting client 9/50, id: 17
# round 2, starting client 10/50, id: 95
# round 2, starting client 11/50, id: 26
# round 2, starting client 12/50, id: 4
# round 2, starting client 13/50, id: 99
# round 2, starting client 14/50, id: 27
# round 2, starting client 15/50, id: 94
# round 2, starting client 16/50, id: 30
# round 2, starting client 17/50, id: 32
# round 2, starting client 18/50, id: 46
# round 2, starting client 19/50, id: 79
# round 2, starting client 20/50, id: 0
# round 2, starting client 21/50, id: 96
# round 2, starting client 22/50, id: 18
# round 2, starting client 23/50, id: 97
# round 2, starting client 24/50, id: 16
# round 2, starting client 25/50, id: 71
# round 2, starting client 26/50, id: 80
# round 2, starting client 27/50, id: 60
# round 2, starting client 28/50, id: 74
# round 2, starting client 29/50, id: 92
# round 2, starting client 30/50, id: 65
# round 2, starting client 31/50, id: 88
# round 2, starting client 32/50, id: 24
# round 2, starting client 33/50, id: 44
# round 2, starting client 34/50, id: 15
# round 2, starting client 35/50, id: 75
# round 2, starting client 36/50, id: 89
# round 2, starting client 37/50, id: 43
# round 2, starting client 38/50, id: 93
# round 2, starting client 39/50, id: 11
# round 2, starting client 40/50, id: 48
# round 2, starting client 41/50, id: 12
# round 2, starting client 42/50, id: 6
# round 2, starting client 43/50, id: 57
# round 2, starting client 44/50, id: 59
# round 2, starting client 45/50, id: 28
# round 2, starting client 46/50, id: 20
# round 2, starting client 47/50, id: 72
# round 2, starting client 48/50, id: 54
# round 2, starting client 49/50, id: 41
# round 2, starting client 50/50, id: 10
# round 2, validation acc: 0.8975
# starting round 3
# clients:  [17 87  9  4 47 62 16 52 33 44 76 19 78 39  6 71 82 66 24 21 74 13 41 92
#   7 65 83 25 63 91 69 95 93 81 77 27 48 56 35 64 86 58 60 46 99 89 37 67
#  90 36]
# round 3, starting client 1/50, id: 17
# round 3, starting client 2/50, id: 87
# round 3, starting client 3/50, id: 9
# round 3, starting client 4/50, id: 4
# round 3, starting client 5/50, id: 47
# round 3, starting client 6/50, id: 62
# round 3, starting client 7/50, id: 16
# round 3, starting client 8/50, id: 52
# round 3, starting client 9/50, id: 33
# round 3, starting client 10/50, id: 44
# round 3, starting client 11/50, id: 76
# round 3, starting client 12/50, id: 19
# round 3, starting client 13/50, id: 78
# round 3, starting client 14/50, id: 39
# round 3, starting client 15/50, id: 6
# round 3, starting client 16/50, id: 71
# round 3, starting client 17/50, id: 82
# round 3, starting client 18/50, id: 66
# round 3, starting client 19/50, id: 24
# round 3, starting client 20/50, id: 21
# round 3, starting client 21/50, id: 74
# round 3, starting client 22/50, id: 13
# round 3, starting client 23/50, id: 41
# round 3, starting client 24/50, id: 92
# round 3, starting client 25/50, id: 7
# round 3, starting client 26/50, id: 65
# round 3, starting client 27/50, id: 83
# round 3, starting client 28/50, id: 25
# round 3, starting client 29/50, id: 63
# round 3, starting client 30/50, id: 91
# round 3, starting client 31/50, id: 69
# round 3, starting client 32/50, id: 95
# round 3, starting client 33/50, id: 93
# round 3, starting client 34/50, id: 81
# round 3, starting client 35/50, id: 77
# round 3, starting client 36/50, id: 27
# round 3, starting client 37/50, id: 48
# round 3, starting client 38/50, id: 56
# round 3, starting client 39/50, id: 35
# round 3, starting client 40/50, id: 64
# round 3, starting client 41/50, id: 86
# round 3, starting client 42/50, id: 58
# round 3, starting client 43/50, id: 60
# round 3, starting client 44/50, id: 46
# round 3, starting client 45/50, id: 99
# round 3, starting client 46/50, id: 89
# round 3, starting client 47/50, id: 37
# round 3, starting client 48/50, id: 67
# round 3, starting client 49/50, id: 90
# round 3, starting client 50/50, id: 36
# round 3, validation acc: 0.9109
# starting round 4
# clients:  [72 22 86 98 83 51 74 75 50 94 71 80 99 44  4 93 10 92 27  3 31 78 55  2
#  64 49 67  5 24 47 70 30 57 28 69 95 21 45 35 11 79 91 82 19 17 53 18  9
#  90 20]
# round 4, starting client 1/50, id: 72
# round 4, starting client 2/50, id: 22
# round 4, starting client 3/50, id: 86
# round 4, starting client 4/50, id: 98
# round 4, starting client 5/50, id: 83
# round 4, starting client 6/50, id: 51
# round 4, starting client 7/50, id: 74
# round 4, starting client 8/50, id: 75
# round 4, starting client 9/50, id: 50
# round 4, starting client 10/50, id: 94
# round 4, starting client 11/50, id: 71
# round 4, starting client 12/50, id: 80
# round 4, starting client 13/50, id: 99
# round 4, starting client 14/50, id: 44
# round 4, starting client 15/50, id: 4
# round 4, starting client 16/50, id: 93
# round 4, starting client 17/50, id: 10
# round 4, starting client 18/50, id: 92
# round 4, starting client 19/50, id: 27
# round 4, starting client 20/50, id: 3
# round 4, starting client 21/50, id: 31
# round 4, starting client 22/50, id: 78
# round 4, starting client 23/50, id: 55
# round 4, starting client 24/50, id: 2
# round 4, starting client 25/50, id: 64
# round 4, starting client 26/50, id: 49
# round 4, starting client 27/50, id: 67
# round 4, starting client 28/50, id: 5
# round 4, starting client 29/50, id: 24
# round 4, starting client 30/50, id: 47
# round 4, starting client 31/50, id: 70
# round 4, starting client 32/50, id: 30
# round 4, starting client 33/50, id: 57
# round 4, starting client 34/50, id: 28
# round 4, starting client 35/50, id: 69
# round 4, starting client 36/50, id: 95
# round 4, starting client 37/50, id: 21
# round 4, starting client 38/50, id: 45
# round 4, starting client 39/50, id: 35
# round 4, starting client 40/50, id: 11
# round 4, starting client 41/50, id: 79
# round 4, starting client 42/50, id: 91
# round 4, starting client 43/50, id: 82
# round 4, starting client 44/50, id: 19
# round 4, starting client 45/50, id: 17
# round 4, starting client 46/50, id: 53
# round 4, starting client 47/50, id: 18
# round 4, starting client 48/50, id: 9
# round 4, starting client 49/50, id: 90
# round 4, starting client 50/50, id: 20
# round 4, validation acc: 0.9178
# starting round 5
# clients:  [25 78 38 52 57 67 72  0  7 15 41 29 42 86 27 75 68  3 82 24 69 85 43 22
#  49 50 13 17 48 31 95  6 61 59 21 11 14 47 40 19 39 33 53 44 18 46 97 76
#  10  2]
# round 5, starting client 1/50, id: 25
# round 5, starting client 2/50, id: 78
# round 5, starting client 3/50, id: 38
# round 5, starting client 4/50, id: 52
# round 5, starting client 5/50, id: 57
# round 5, starting client 6/50, id: 67
# round 5, starting client 7/50, id: 72
# round 5, starting client 8/50, id: 0
# round 5, starting client 9/50, id: 7
# round 5, starting client 10/50, id: 15
# round 5, starting client 11/50, id: 41
# round 5, starting client 12/50, id: 29
# round 5, starting client 13/50, id: 42
# round 5, starting client 14/50, id: 86
# round 5, starting client 15/50, id: 27
# round 5, starting client 16/50, id: 75
# round 5, starting client 17/50, id: 68
# round 5, starting client 18/50, id: 3
# round 5, starting client 19/50, id: 82
# round 5, starting client 20/50, id: 24
# round 5, starting client 21/50, id: 69
# round 5, starting client 22/50, id: 85
# round 5, starting client 23/50, id: 43
# round 5, starting client 24/50, id: 22
# round 5, starting client 25/50, id: 49
# round 5, starting client 26/50, id: 50
# round 5, starting client 27/50, id: 13
# round 5, starting client 28/50, id: 17
# round 5, starting client 29/50, id: 48
# round 5, starting client 30/50, id: 31
# round 5, starting client 31/50, id: 95
# round 5, starting client 32/50, id: 6
# round 5, starting client 33/50, id: 61
# round 5, starting client 34/50, id: 59
# round 5, starting client 35/50, id: 21
# round 5, starting client 36/50, id: 11
# round 5, starting client 37/50, id: 14
# round 5, starting client 38/50, id: 47
# round 5, starting client 39/50, id: 40
# round 5, starting client 40/50, id: 19
# round 5, starting client 41/50, id: 39
# round 5, starting client 42/50, id: 33
# round 5, starting client 43/50, id: 53
# round 5, starting client 44/50, id: 44
# round 5, starting client 45/50, id: 18
# round 5, starting client 46/50, id: 46
# round 5, starting client 47/50, id: 97
# round 5, starting client 48/50, id: 76
# round 5, starting client 49/50, id: 10
# round 5, starting client 50/50, id: 2
# round 5, validation acc: 0.9241
# starting round 6
# clients:  [32  4 26 83 63 76  1 46 50 57 62 19 47  9  7 69  6 93 67 30 51 22 59 55
#  25 40  0 41 39 98 71 13 89 74 90 56 10 91 82 28 68 20 95 73 85 88 53 81
#   2 37]
# round 6, starting client 1/50, id: 32
# round 6, starting client 2/50, id: 4
# round 6, starting client 3/50, id: 26
# round 6, starting client 4/50, id: 83
# round 6, starting client 5/50, id: 63
# round 6, starting client 6/50, id: 76
# round 6, starting client 7/50, id: 1
# round 6, starting client 8/50, id: 46
# round 6, starting client 9/50, id: 50
# round 6, starting client 10/50, id: 57
# round 6, starting client 11/50, id: 62
# round 6, starting client 12/50, id: 19
# round 6, starting client 13/50, id: 47
# round 6, starting client 14/50, id: 9
# round 6, starting client 15/50, id: 7
# round 6, starting client 16/50, id: 69
# round 6, starting client 17/50, id: 6
# round 6, starting client 18/50, id: 93
# round 6, starting client 19/50, id: 67
# round 6, starting client 20/50, id: 30
# round 6, starting client 21/50, id: 51
# round 6, starting client 22/50, id: 22
# round 6, starting client 23/50, id: 59
# round 6, starting client 24/50, id: 55
# round 6, starting client 25/50, id: 25
# round 6, starting client 26/50, id: 40
# round 6, starting client 27/50, id: 0
# round 6, starting client 28/50, id: 41
# round 6, starting client 29/50, id: 39
# round 6, starting client 30/50, id: 98
# round 6, starting client 31/50, id: 71
# round 6, starting client 32/50, id: 13
# round 6, starting client 33/50, id: 89
# round 6, starting client 34/50, id: 74
# round 6, starting client 35/50, id: 90
# round 6, starting client 36/50, id: 56
# round 6, starting client 37/50, id: 10
# round 6, starting client 38/50, id: 91
# round 6, starting client 39/50, id: 82
# round 6, starting client 40/50, id: 28
# round 6, starting client 41/50, id: 68
# round 6, starting client 42/50, id: 20
# round 6, starting client 43/50, id: 95
# round 6, starting client 44/50, id: 73
# round 6, starting client 45/50, id: 85
# round 6, starting client 46/50, id: 88
# round 6, starting client 47/50, id: 53
# round 6, starting client 48/50, id: 81
# round 6, starting client 49/50, id: 2
# round 6, starting client 50/50, id: 37
# round 6, validation acc: 0.9284
# starting round 7
# clients:  [77 72 22 53 26 66 37 58 82  2 36 33 91 45 78 10  7 48 67 29 41  4 92 85
#   8 68 99 56 75 54 63 30 14 28 80  0 87 42 94 52  1 32 34 84 11 17 61  3
#  12 90]
# round 7, starting client 1/50, id: 77
# round 7, starting client 2/50, id: 72
# round 7, starting client 3/50, id: 22
# round 7, starting client 4/50, id: 53
# round 7, starting client 5/50, id: 26
# round 7, starting client 6/50, id: 66
# round 7, starting client 7/50, id: 37
# round 7, starting client 8/50, id: 58
# round 7, starting client 9/50, id: 82
# round 7, starting client 10/50, id: 2
# round 7, starting client 11/50, id: 36
# round 7, starting client 12/50, id: 33
# round 7, starting client 13/50, id: 91
# round 7, starting client 14/50, id: 45
# round 7, starting client 15/50, id: 78
# round 7, starting client 16/50, id: 10
# round 7, starting client 17/50, id: 7
# round 7, starting client 18/50, id: 48
# round 7, starting client 19/50, id: 67
# round 7, starting client 20/50, id: 29
# round 7, starting client 21/50, id: 41
# round 7, starting client 22/50, id: 4
# round 7, starting client 23/50, id: 92
# round 7, starting client 24/50, id: 85
# round 7, starting client 25/50, id: 8
# round 7, starting client 26/50, id: 68
# round 7, starting client 27/50, id: 99
# round 7, starting client 28/50, id: 56
# round 7, starting client 29/50, id: 75
# round 7, starting client 30/50, id: 54
# round 7, starting client 31/50, id: 63
# round 7, starting client 32/50, id: 30
# round 7, starting client 33/50, id: 14
# round 7, starting client 34/50, id: 28
# round 7, starting client 35/50, id: 80
# round 7, starting client 36/50, id: 0
# round 7, starting client 37/50, id: 87
# round 7, starting client 38/50, id: 42
# round 7, starting client 39/50, id: 94
# round 7, starting client 40/50, id: 52
# round 7, starting client 41/50, id: 1
# round 7, starting client 42/50, id: 32
# round 7, starting client 43/50, id: 34
# round 7, starting client 44/50, id: 84
# round 7, starting client 45/50, id: 11
# round 7, starting client 46/50, id: 17
# round 7, starting client 47/50, id: 61
# round 7, starting client 48/50, id: 3
# round 7, starting client 49/50, id: 12
# round 7, starting client 50/50, id: 90
# round 7, validation acc: 0.934
# starting round 8
# clients:  [ 7 19 69 76 35 11 45 20 73 30 55  6 21  1 97 36 27 10 18 94 67  0 66 52
#  49 68  2 42 95 91 84 87 51  4 54 46  3 89 53 38 13 12 92 61 17 50 75 34
#  82 79]
# round 8, starting client 1/50, id: 7
# round 8, starting client 2/50, id: 19
# round 8, starting client 3/50, id: 69
# round 8, starting client 4/50, id: 76
# round 8, starting client 5/50, id: 35
# round 8, starting client 6/50, id: 11
# round 8, starting client 7/50, id: 45
# round 8, starting client 8/50, id: 20
# round 8, starting client 9/50, id: 73
# round 8, starting client 10/50, id: 30
# round 8, starting client 11/50, id: 55
# round 8, starting client 12/50, id: 6
# round 8, starting client 13/50, id: 21
# round 8, starting client 14/50, id: 1
# round 8, starting client 15/50, id: 97
# round 8, starting client 16/50, id: 36
# round 8, starting client 17/50, id: 27
# round 8, starting client 18/50, id: 10
# round 8, starting client 19/50, id: 18
# round 8, starting client 20/50, id: 94
# round 8, starting client 21/50, id: 67
# round 8, starting client 22/50, id: 0
# round 8, starting client 23/50, id: 66
# round 8, starting client 24/50, id: 52
# round 8, starting client 25/50, id: 49
# round 8, starting client 26/50, id: 68
# round 8, starting client 27/50, id: 2
# round 8, starting client 28/50, id: 42
# round 8, starting client 29/50, id: 95
# round 8, starting client 30/50, id: 91
# round 8, starting client 31/50, id: 84
# round 8, starting client 32/50, id: 87
# round 8, starting client 33/50, id: 51
# round 8, starting client 34/50, id: 4
# round 8, starting client 35/50, id: 54
# round 8, starting client 36/50, id: 46
# round 8, starting client 37/50, id: 3
# round 8, starting client 38/50, id: 89
# round 8, starting client 39/50, id: 53
# round 8, starting client 40/50, id: 38
# round 8, starting client 41/50, id: 13
# round 8, starting client 42/50, id: 12
# round 8, starting client 43/50, id: 92
# round 8, starting client 44/50, id: 61
# round 8, starting client 45/50, id: 17
# round 8, starting client 46/50, id: 50
# round 8, starting client 47/50, id: 75
# round 8, starting client 48/50, id: 34
# round 8, starting client 49/50, id: 82
# round 8, starting client 50/50, id: 79
# round 8, validation acc: 0.9362
# starting round 9
# clients:  [49 47 23 12 67 11 89 40  4 69 64  7 10 71 37 63 54 51 86 87 60  1 46 70
#  62 88  8 66 73 39 61 94 48 92 83 76 26 78 90 34 58  0  3 15 93 72 44 24
#  57 82]
# round 9, starting client 1/50, id: 49
# round 9, starting client 2/50, id: 47
# round 9, starting client 3/50, id: 23
# round 9, starting client 4/50, id: 12
# round 9, starting client 5/50, id: 67
# round 9, starting client 6/50, id: 11
# round 9, starting client 7/50, id: 89
# round 9, starting client 8/50, id: 40
# round 9, starting client 9/50, id: 4
# round 9, starting client 10/50, id: 69
# round 9, starting client 11/50, id: 64
# round 9, starting client 12/50, id: 7
# round 9, starting client 13/50, id: 10
# round 9, starting client 14/50, id: 71
# round 9, starting client 15/50, id: 37
# round 9, starting client 16/50, id: 63
# round 9, starting client 17/50, id: 54
# round 9, starting client 18/50, id: 51
# round 9, starting client 19/50, id: 86
# round 9, starting client 20/50, id: 87
# round 9, starting client 21/50, id: 60
# round 9, starting client 22/50, id: 1
# round 9, starting client 23/50, id: 46
# round 9, starting client 24/50, id: 70
# round 9, starting client 25/50, id: 62
# round 9, starting client 26/50, id: 88
# round 9, starting client 27/50, id: 8
# round 9, starting client 28/50, id: 66
# round 9, starting client 29/50, id: 73
# round 9, starting client 30/50, id: 39
# round 9, starting client 31/50, id: 61
# round 9, starting client 32/50, id: 94
# round 9, starting client 33/50, id: 48
# round 9, starting client 34/50, id: 92
# round 9, starting client 35/50, id: 83
# round 9, starting client 36/50, id: 76
# round 9, starting client 37/50, id: 26
# round 9, starting client 38/50, id: 78
# round 9, starting client 39/50, id: 90
# round 9, starting client 40/50, id: 34
# round 9, starting client 41/50, id: 58
# round 9, starting client 42/50, id: 0
# round 9, starting client 43/50, id: 3
# round 9, starting client 44/50, id: 15
# round 9, starting client 45/50, id: 93
# round 9, starting client 46/50, id: 72
# round 9, starting client 47/50, id: 44
# round 9, starting client 48/50, id: 24
# round 9, starting client 49/50, id: 57
# round 9, starting client 50/50, id: 82
# round 9, validation acc: 0.9384
# [0.8165 0.8781 0.8975 0.9109 0.9178 0.9241 0.9284 0.934  0.9362 0.9384]

# %%
# MLP - non-iid - m=10 experiment
mlp_noniid_m10 = copy.deepcopy(mlp)
acc_mlp_noniid_m10 = fed_avg_experiment(mlp_noniid_m10, num_clients_per_round=10, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=300,
                                 filename = './acc_mlp_noniid_m10')
print(acc_mlp_noniid_m10)
np.save('./acc_mlp_noniid_m10.npy', acc_mlp_noniid_m10)

# %%
# MLP - noniid - m=50 experiment
mlp_noniid_m50 = copy.deepcopy(mlp)
acc_mlp_noniid_m50 = fed_avg_experiment(mlp_noniid_m50, num_clients_per_round=50, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=300,
                                 filename='./acc_mlp_noniid_m50')
print(acc_mlp_noniid_m50)
np.save('./acc_mlp_noniid_m50.npy', acc_mlp_noniid_m50)

# %% [markdown]
# ## CNN Experiments

# %%
cnn = CNN()
print(cnn)
print("total params: ", num_params(cnn))
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=10, bias=True)
# )
# total params:  582026

# %%
# CNN - iid - m=10 experiment
cnn_iid_m10 = copy.deepcopy(cnn)
acc_cnn_iid_m10 = fed_avg_experiment(cnn_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=10,
                                 filename='./acc_cnn_iid_m10')
print(acc_cnn_iid_m10)
np.save('./acc_cnn_iid_m10.npy', acc_cnn_iid_m10)
# Out:
# starting round 0
# clients:  [ 2 83 35 43 26 13 69 29 65 80]
# round 0, starting client 1/10, id: 2
# round 0, starting client 2/10, id: 83
# round 0, starting client 3/10, id: 35
# round 0, starting client 4/10, id: 43
# round 0, starting client 5/10, id: 26
# round 0, starting client 6/10, id: 13
# round 0, starting client 7/10, id: 69
# round 0, starting client 8/10, id: 29
# round 0, starting client 9/10, id: 65
# round 0, starting client 10/10, id: 80
# round 0, validation acc: 0.9164
# starting round 1
# clients:  [68 94 73 61 28 21 90 15 80  4]
# round 1, starting client 1/10, id: 68
# round 1, starting client 2/10, id: 94
# round 1, starting client 3/10, id: 73
# round 1, starting client 4/10, id: 61
# round 1, starting client 5/10, id: 28
# round 1, starting client 6/10, id: 21
# round 1, starting client 7/10, id: 90
# round 1, starting client 8/10, id: 15
# round 1, starting client 9/10, id: 80
# round 1, starting client 10/10, id: 4
# round 1, validation acc: 0.9399
# starting round 2
# clients:  [88 94 57 79  5 31 18 17 22  2]
# round 2, starting client 1/10, id: 88
# round 2, starting client 2/10, id: 94
# round 2, starting client 3/10, id: 57
# round 2, starting client 4/10, id: 79
# round 2, starting client 5/10, id: 5
# round 2, starting client 6/10, id: 31
# round 2, starting client 7/10, id: 18
# round 2, starting client 8/10, id: 17
# round 2, starting client 9/10, id: 22
# round 2, starting client 10/10, id: 2
# round 2, validation acc: 0.9532
# starting round 3
# clients:  [13 98 54 80 67 12  9 25 78 66]
# round 3, starting client 1/10, id: 13
# round 3, starting client 2/10, id: 98
# round 3, starting client 3/10, id: 54
# round 3, starting client 4/10, id: 80
# round 3, starting client 5/10, id: 67
# round 3, starting client 6/10, id: 12
# round 3, starting client 7/10, id: 9
# round 3, starting client 8/10, id: 25
# round 3, starting client 9/10, id: 78
# round 3, starting client 10/10, id: 66
# round 3, validation acc: 0.9606
# starting round 4
# clients:  [83 36 71 44 49  9 24 37 10 30]
# round 4, starting client 1/10, id: 83
# round 4, starting client 2/10, id: 36
# round 4, starting client 3/10, id: 71
# round 4, starting client 4/10, id: 44
# round 4, starting client 5/10, id: 49
# round 4, starting client 6/10, id: 9
# round 4, starting client 7/10, id: 24
# round 4, starting client 8/10, id: 37
# round 4, starting client 9/10, id: 10
# round 4, starting client 10/10, id: 30
# round 4, validation acc: 0.9651
# starting round 5
# clients:  [87 56 88 78 86 26  4 92 54 17]
# round 5, starting client 1/10, id: 87
# round 5, starting client 2/10, id: 56
# round 5, starting client 3/10, id: 88
# round 5, starting client 4/10, id: 78
# round 5, starting client 5/10, id: 86
# round 5, starting client 6/10, id: 26
# round 5, starting client 7/10, id: 4
# round 5, starting client 8/10, id: 92
# round 5, starting client 9/10, id: 54
# round 5, starting client 10/10, id: 17
# round 5, validation acc: 0.9685
# starting round 6
# clients:  [14 77 43 74  1 40 94 78 57 24]
# round 6, starting client 1/10, id: 14
# round 6, starting client 2/10, id: 77
# round 6, starting client 3/10, id: 43
# round 6, starting client 4/10, id: 74
# round 6, starting client 5/10, id: 1
# round 6, starting client 6/10, id: 40
# round 6, starting client 7/10, id: 94
# round 6, starting client 8/10, id: 78
# round 6, starting client 9/10, id: 57
# round 6, starting client 10/10, id: 24
# round 6, validation acc: 0.9707
# starting round 7
# clients:  [82 47 88 70 74 61 35 52 97 95]
# round 7, starting client 1/10, id: 82
# round 7, starting client 2/10, id: 47
# round 7, starting client 3/10, id: 88
# round 7, starting client 4/10, id: 70
# round 7, starting client 5/10, id: 74
# round 7, starting client 6/10, id: 61
# round 7, starting client 7/10, id: 35
# round 7, starting client 8/10, id: 52
# round 7, starting client 9/10, id: 97
# round 7, starting client 10/10, id: 95
# round 7, validation acc: 0.973
# starting round 8
# clients:  [12 32 64 11 50 15 95 78 63  8]
# round 8, starting client 1/10, id: 12
# round 8, starting client 2/10, id: 32
# round 8, starting client 3/10, id: 64
# round 8, starting client 4/10, id: 11
# round 8, starting client 5/10, id: 50
# round 8, starting client 6/10, id: 15
# round 8, starting client 7/10, id: 95
# round 8, starting client 8/10, id: 78
# round 8, starting client 9/10, id: 63
# round 8, starting client 10/10, id: 8
# round 8, validation acc: 0.9741
# starting round 9
# clients:  [ 2 25 75  4 32 41 54 88 72 58]
# round 9, starting client 1/10, id: 2
# round 9, starting client 2/10, id: 25
# round 9, starting client 3/10, id: 75
# round 9, starting client 4/10, id: 4
# round 9, starting client 5/10, id: 32
# round 9, starting client 6/10, id: 41
# round 9, starting client 7/10, id: 54
# round 9, starting client 8/10, id: 88
# round 9, starting client 9/10, id: 72
# round 9, starting client 10/10, id: 58
# round 9, validation acc: 0.9752
# [0.9164 0.9399 0.9532 0.9606 0.9651 0.9685 0.9707 0.973  0.9741 0.9752]

# %%
# CNN - iid - m=50 experiment
cnn_iid_m50 = copy.deepcopy(cnn)
acc_cnn_iid_m50 = fed_avg_experiment(cnn_iid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=5,
                                 filename='./acc_cnn_iid_m50')
print(acc_cnn_iid_m50)
np.save('./acc_cnn_iid_m50.npy', acc_cnn_iid_m50)
# Out:
# starting round 0
# clients:  [37 27 61 26 63 87 11 24  2 86 32  4  6 29 16 98 62 71  3 15 54 41 49 79
#  89 81 77 50 95 76 84 40 10 94 70 69 36 43 45 67 48 47 23 51 30  9 28 60
#  64 74]
# round 0, starting client 1/50, id: 37
# round 0, starting client 2/50, id: 27
# round 0, starting client 3/50, id: 61
# round 0, starting client 4/50, id: 26
# round 0, starting client 5/50, id: 63
# round 0, starting client 6/50, id: 87
# round 0, starting client 7/50, id: 11
# round 0, starting client 8/50, id: 24
# round 0, starting client 9/50, id: 2
# round 0, starting client 10/50, id: 86
# round 0, starting client 11/50, id: 32
# round 0, starting client 12/50, id: 4
# round 0, starting client 13/50, id: 6
# round 0, starting client 14/50, id: 29
# round 0, starting client 15/50, id: 16
# round 0, starting client 16/50, id: 98
# round 0, starting client 17/50, id: 62
# round 0, starting client 18/50, id: 71
# round 0, starting client 19/50, id: 3
# round 0, starting client 20/50, id: 15
# round 0, starting client 21/50, id: 54
# round 0, starting client 22/50, id: 41
# round 0, starting client 23/50, id: 49
# round 0, starting client 24/50, id: 79
# round 0, starting client 25/50, id: 89
# round 0, starting client 26/50, id: 81
# round 0, starting client 27/50, id: 77
# round 0, starting client 28/50, id: 50
# round 0, starting client 29/50, id: 95
# round 0, starting client 30/50, id: 76
# round 0, starting client 31/50, id: 84
# round 0, starting client 32/50, id: 40
# round 0, starting client 33/50, id: 10
# round 0, starting client 34/50, id: 94
# round 0, starting client 35/50, id: 70
# round 0, starting client 36/50, id: 69
# round 0, starting client 37/50, id: 36
# round 0, starting client 38/50, id: 43
# round 0, starting client 39/50, id: 45
# round 0, starting client 40/50, id: 67
# round 0, starting client 41/50, id: 48
# round 0, starting client 42/50, id: 47
# round 0, starting client 43/50, id: 23
# round 0, starting client 44/50, id: 51
# round 0, starting client 45/50, id: 30
# round 0, starting client 46/50, id: 9
# round 0, starting client 47/50, id: 28
# round 0, starting client 48/50, id: 60
# round 0, starting client 49/50, id: 64
# round 0, starting client 50/50, id: 74
# round 0, validation acc: 0.9157
# starting round 1
# clients:  [61 68 13 57 45 16 55 85 40 74 39 35  4 91 97 65 72 20 43 98 53 83 30 66
#   9 17 25 80 67 41 77  1 93 90 50 23 47 62 48 31 49 78 32 14 22 88 10 26
#  99 24]
# round 1, starting client 1/50, id: 61
# round 1, starting client 2/50, id: 68
# round 1, starting client 3/50, id: 13
# round 1, starting client 4/50, id: 57
# round 1, starting client 5/50, id: 45
# round 1, starting client 6/50, id: 16
# round 1, starting client 7/50, id: 55
# round 1, starting client 8/50, id: 85
# round 1, starting client 9/50, id: 40
# round 1, starting client 10/50, id: 74
# round 1, starting client 11/50, id: 39
# round 1, starting client 12/50, id: 35
# round 1, starting client 13/50, id: 4
# round 1, starting client 14/50, id: 91
# round 1, starting client 15/50, id: 97
# round 1, starting client 16/50, id: 65
# round 1, starting client 17/50, id: 72
# round 1, starting client 18/50, id: 20
# round 1, starting client 19/50, id: 43
# round 1, starting client 20/50, id: 98
# round 1, starting client 21/50, id: 53
# round 1, starting client 22/50, id: 83
# round 1, starting client 23/50, id: 30
# round 1, starting client 24/50, id: 66
# round 1, starting client 25/50, id: 9
# round 1, starting client 26/50, id: 17
# round 1, starting client 27/50, id: 25
# round 1, starting client 28/50, id: 80
# round 1, starting client 29/50, id: 67
# round 1, starting client 30/50, id: 41
# round 1, starting client 31/50, id: 77
# round 1, starting client 32/50, id: 1
# round 1, starting client 33/50, id: 93
# round 1, starting client 34/50, id: 90
# round 1, starting client 35/50, id: 50
# round 1, starting client 36/50, id: 23
# round 1, starting client 37/50, id: 47
# round 1, starting client 38/50, id: 62
# round 1, starting client 39/50, id: 48
# round 1, starting client 40/50, id: 31
# round 1, starting client 41/50, id: 49
# round 1, starting client 42/50, id: 78
# round 1, starting client 43/50, id: 32
# round 1, starting client 44/50, id: 14
# round 1, starting client 45/50, id: 22
# round 1, starting client 46/50, id: 88
# round 1, starting client 47/50, id: 10
# round 1, starting client 48/50, id: 26
# round 1, starting client 49/50, id: 99
# round 1, starting client 50/50, id: 24
# round 1, validation acc: 0.9413
# starting round 2
# clients:  [76 24 94 60 81  4  2 26 23 73 57  6 56 18 34 36 80  7 25 92 15 50 39 84
#  42 47 65 59 54 46 37 71 87 72 30 49 33 61 89 98 13 91 62 45 19 51 48 99
#  70 93]
# round 2, starting client 1/50, id: 76
# round 2, starting client 2/50, id: 24
# round 2, starting client 3/50, id: 94
# round 2, starting client 4/50, id: 60
# round 2, starting client 5/50, id: 81
# round 2, starting client 6/50, id: 4
# round 2, starting client 7/50, id: 2
# round 2, starting client 8/50, id: 26
# round 2, starting client 9/50, id: 23
# round 2, starting client 10/50, id: 73
# round 2, starting client 11/50, id: 57
# round 2, starting client 12/50, id: 6
# round 2, starting client 13/50, id: 56
# round 2, starting client 14/50, id: 18
# round 2, starting client 15/50, id: 34
# round 2, starting client 16/50, id: 36
# round 2, starting client 17/50, id: 80
# round 2, starting client 18/50, id: 7
# round 2, starting client 19/50, id: 25
# round 2, starting client 20/50, id: 92
# round 2, starting client 21/50, id: 15
# round 2, starting client 22/50, id: 50
# round 2, starting client 23/50, id: 39
# round 2, starting client 24/50, id: 84
# round 2, starting client 25/50, id: 42
# round 2, starting client 26/50, id: 47
# round 2, starting client 27/50, id: 65
# round 2, starting client 28/50, id: 59
# round 2, starting client 29/50, id: 54
# round 2, starting client 30/50, id: 46
# round 2, starting client 31/50, id: 37
# round 2, starting client 32/50, id: 71
# round 2, starting client 33/50, id: 87
# round 2, starting client 34/50, id: 72
# round 2, starting client 35/50, id: 30
# round 2, starting client 36/50, id: 49
# round 2, starting client 37/50, id: 33
# round 2, starting client 38/50, id: 61
# round 2, starting client 39/50, id: 89
# round 2, starting client 40/50, id: 98
# round 2, starting client 41/50, id: 13
# round 2, starting client 42/50, id: 91
# round 2, starting client 43/50, id: 62
# round 2, starting client 44/50, id: 45
# round 2, starting client 45/50, id: 19
# round 2, starting client 46/50, id: 51
# round 2, starting client 47/50, id: 48
# round 2, starting client 48/50, id: 99
# round 2, starting client 49/50, id: 70
# round 2, starting client 50/50, id: 93
# round 2, validation acc: 0.9526
# starting round 3
# clients:  [73 11 87 30 19 13 21 17 33 83 12 22  9 35 96 48 15 10 37  0 63 53  8 41
#  45 60 39 82 44 98  1 90 84 54 92 62 51 67 24  6 75 70 50 79 14 94 61 93
#   7 32]
# round 3, starting client 1/50, id: 73
# round 3, starting client 2/50, id: 11
# round 3, starting client 3/50, id: 87
# round 3, starting client 4/50, id: 30
# round 3, starting client 5/50, id: 19
# round 3, starting client 6/50, id: 13
# round 3, starting client 7/50, id: 21
# round 3, starting client 8/50, id: 17
# round 3, starting client 9/50, id: 33
# round 3, starting client 10/50, id: 83
# round 3, starting client 11/50, id: 12
# round 3, starting client 12/50, id: 22
# round 3, starting client 13/50, id: 9
# round 3, starting client 14/50, id: 35
# round 3, starting client 15/50, id: 96
# round 3, starting client 16/50, id: 48
# round 3, starting client 17/50, id: 15
# round 3, starting client 18/50, id: 10
# round 3, starting client 19/50, id: 37
# round 3, starting client 20/50, id: 0
# round 3, starting client 21/50, id: 63
# round 3, starting client 22/50, id: 53
# round 3, starting client 23/50, id: 8
# round 3, starting client 24/50, id: 41
# round 3, starting client 25/50, id: 45
# round 3, starting client 26/50, id: 60
# round 3, starting client 27/50, id: 39
# round 3, starting client 28/50, id: 82
# round 3, starting client 29/50, id: 44
# round 3, starting client 30/50, id: 98
# round 3, starting client 31/50, id: 1
# round 3, starting client 32/50, id: 90
# round 3, starting client 33/50, id: 84
# round 3, starting client 34/50, id: 54
# round 3, starting client 35/50, id: 92
# round 3, starting client 36/50, id: 62
# round 3, starting client 37/50, id: 51
# round 3, starting client 38/50, id: 67
# round 3, starting client 39/50, id: 24
# round 3, starting client 40/50, id: 6
# round 3, starting client 41/50, id: 75
# round 3, starting client 42/50, id: 70
# round 3, starting client 43/50, id: 50
# round 3, starting client 44/50, id: 79
# round 3, starting client 45/50, id: 14
# round 3, starting client 46/50, id: 94
# round 3, starting client 47/50, id: 61
# round 3, starting client 48/50, id: 93
# round 3, starting client 49/50, id: 7
# round 3, starting client 50/50, id: 32
# round 3, validation acc: 0.961
# starting round 4
# clients:  [20 35 30 99  9  7 17 78 70 16  8 13 90 80 63 82 25 83  4 53 84 75 29 73
#  43 56  6 42 45  2 69 48 11 22 28 33 67 66 12 71 19 87 93 92 88 86 91 74
#   3 44]
# round 4, starting client 1/50, id: 20
# round 4, starting client 2/50, id: 35
# round 4, starting client 3/50, id: 30
# round 4, starting client 4/50, id: 99
# round 4, starting client 5/50, id: 9
# round 4, starting client 6/50, id: 7
# round 4, starting client 7/50, id: 17
# round 4, starting client 8/50, id: 78
# round 4, starting client 9/50, id: 70
# round 4, starting client 10/50, id: 16
# round 4, starting client 11/50, id: 8
# round 4, starting client 12/50, id: 13
# round 4, starting client 13/50, id: 90
# round 4, starting client 14/50, id: 80
# round 4, starting client 15/50, id: 63
# round 4, starting client 16/50, id: 82
# round 4, starting client 17/50, id: 25
# round 4, starting client 18/50, id: 83
# round 4, starting client 19/50, id: 4
# round 4, starting client 20/50, id: 53
# round 4, starting client 21/50, id: 84
# round 4, starting client 22/50, id: 75
# round 4, starting client 23/50, id: 29
# round 4, starting client 24/50, id: 73
# round 4, starting client 25/50, id: 43
# round 4, starting client 26/50, id: 56
# round 4, starting client 27/50, id: 6
# round 4, starting client 28/50, id: 42
# round 4, starting client 29/50, id: 45
# round 4, starting client 30/50, id: 2
# round 4, starting client 31/50, id: 69
# round 4, starting client 32/50, id: 48
# round 4, starting client 33/50, id: 11
# round 4, starting client 34/50, id: 22
# round 4, starting client 35/50, id: 28
# round 4, starting client 36/50, id: 33
# round 4, starting client 37/50, id: 67
# round 4, starting client 38/50, id: 66
# round 4, starting client 39/50, id: 12
# round 4, starting client 40/50, id: 71
# round 4, starting client 41/50, id: 19
# round 4, starting client 42/50, id: 87
# round 4, starting client 43/50, id: 93
# round 4, starting client 44/50, id: 92
# round 4, starting client 45/50, id: 88
# round 4, starting client 46/50, id: 86
# round 4, starting client 47/50, id: 91
# round 4, starting client 48/50, id: 74
# round 4, starting client 49/50, id: 3
# round 4, starting client 50/50, id: 44
# round 4, validation acc: 0.9666
# [0.9157 0.9413 0.9526 0.961  0.9666]

# %%
# CNN - non-iid - m=10 experiment
cnn_noniid_m10 = copy.deepcopy(cnn)
acc_cnn_noniid_m10 = fed_avg_experiment(cnn_noniid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=200,
                                 filename='./acc_cnn_noniid_m10')
print(acc_cnn_noniid_m10)
np.save('./acc_cnn_noniid_m10.npy', acc_cnn_noniid_m10)

# %%
# CNN - non-iid - m=50 experiment
cnn_noniid_m50 = copy.deepcopy(cnn)
acc_cnn_noniid_m50 = fed_avg_experiment(cnn_noniid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_noniid_m50')
print(acc_cnn_noniid_m50)
np.save('./acc_cnn_noniid_m50.npy', acc_cnn_noniid_m50)

# %%
# view_10(x_debug[:10].to(cpu), torch.argmax(model(x_debug),dim=1)[:10].to(cpu))

# m = CNN().to(device)
# m.train()
# lr = 0.01
# opt = torch.optim.SGD(m.parameters(), lr)

# for epoch in range(5):
#     for (t, (x,y)) in enumerate(train_loader):
#         x = x.to(device)
#         y = y.to(device)
#         opt.zero_grad()
#         out = m(x)
#         loss = criterion(out, y)
#         loss.backward()
#         opt.step()

#         if (t%100 == 0):
#             print("epoch {}, step {}, loss: {}".format(epoch, t, loss))

#     print("running validation")
#     acc = validate(m)
#     print("epoch {} validation acc: {}".format(epoch, acc))
